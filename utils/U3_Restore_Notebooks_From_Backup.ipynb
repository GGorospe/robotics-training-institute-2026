# %% [markdown]
# # U3 - Utilities: Restore Notebooks from Backup
# Author: George Gorospe, george.gorospe@nmaia.net (updated 7/20/2026)
# **Repo: *robotics-training-institute-2026***
#
#
# ## This utility notebook is used to restore the notebooks to their original form. Use this notebook when you're having trouble with the code or getting an error you just can't get around.
# ## *** This notebook restores your notebooks without needing access to the internet.***
#
# ## *** IMPORTANT: You must close all other noteboks before running this code! ***

# %%
# Step 1: Check if the backup folder exists.
import os
backupExists = os.path.exists("/home/explorer/.Backup/robotics-training-institute-2026")

# Decision Point: if backup exists, we pull from the backup to overwrite the local changes, this is good if we broke something
#                 if the backup doesn't exist, direct user to U1_Pull_Updates notebook 

if backupExists:
    print("Restoring notebooks from backup! Any open notebooks will be overwritten, revert to file on disk if prompted.")
    # Copy original files from backup directory overwiting the current files.
    # !cp -f /home/explorer/.Backup/robotics-training-institute-2026/*.ipynb .
elif backupExists == False:
    print("No backup files located on disk, use U1_Pull_Updates noteboot to load a backup.")
